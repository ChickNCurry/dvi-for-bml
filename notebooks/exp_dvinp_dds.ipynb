# %%
import torch
import wandb
from hydra import compose, initialize

from dviforbml.evaluation.visualization.visualize_dvinp import visualize_dvinp
from dviforbml.evaluation.visualization.visualize_task import visualize_task
from dviforbml.utils.helper import download_run_np, get_name_dvinp
from dviforbml.utils.load_dvinp import load_dvinp

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
try:
    import torch_directml

    device = torch_directml.device()
except ImportError:
    device = torch.device("cpu")

# device = torch.device("cpu")

# %%
# project = "cluster-dvinp-linesine"
# name = "16-None-mean-cos-dis-True-cntxt"  # "16-1-bca-free-dis-True-False-context-1.0-0"
# dir = download_run(project, name)

dir = "../models/dvinp"

# %%
from dviforbml.utils.load_ddsnp import load_ddsnp


with initialize(version_base=None, config_path=dir):
    cfg = compose(config_name="cfg")

    model, trainer, test_loader, _ = load_ddsnp(
        cfg=cfg,
        device=device,
        dir=dir,
        load_decoder_only=True,
        train_decoder=True,
        debugging=False,
    )
# Out:
# Generating tasks: 100%|██████████| 1024/1024 [00:00<00:00, 321696.30it/s]
# Dropped Escape call with ulEscapeCode : 0x03007703
# loaded decoder from ../models/dvinp/decoder.pth
# loaded encoder from ../models/dvinp/encoder.pth

# %%
# torch.save(model.decoder.state_dict(), f"{dir}/decoder.pth")

# %%
visualize_task(test_loader)

# %%
trainer.wandb_logging = True
if trainer.wandb_logging:
    wandb.init(project="2-tasks", name=get_name_dvinp(cfg))
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: max-burzer (max-burzer-karlsruhe-institute-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/home/chickencurry/dviforbml/notebooks/wandb/run-20250415_154356-vijpo7vs</code>
# Syncing run <strong><a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/2-tasks/runs/vijpo7vs' target="_blank">16-1-mean-dis-free-True-cntxt-0</a></strong> to <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/2-tasks' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/2-tasks' target="_blank">https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/2-tasks</a>
#  View run at <a href='https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/2-tasks/runs/vijpo7vs' target="_blank">https://wandb.ai/max-burzer-karlsruhe-institute-of-technology/2-tasks/runs/vijpo7vs</a>

# %%
model.freeze_encoder()
model.freeze_decoder()

train = True

if train:
    # trainer.optimizer.param_groups[0]["lr"] = 0.1 * cfg.training.learning_rate
    # print(trainer.optimizer.param_groups[0]["lr"])

    num_epochs = 200
    losses = trainer.train(
        num_epochs=num_epochs,
        max_clip_norm=cfg.training.max_clip_norm,
        alpha=None,
        validate=False,
    )

    # torch.save(dvinp.state_dict(), f"{dir}/dvinp.pth")
# Out:
# 100%|██████████| 8/8 [00:01<00:00,  5.73it/s, epoch=0, loss=259, lmpl=-17.4, mse=9.34]
# 100%|██████████| 8/8 [00:01<00:00,  5.89it/s, epoch=1, loss=246, lmpl=-17, mse=9.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s, epoch=2, loss=242, lmpl=-16.3, mse=9.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.09it/s, epoch=3, loss=201, lmpl=-19.2, mse=13.5]
# 100%|██████████| 8/8 [00:01<00:00,  5.99it/s, epoch=4, loss=304, lmpl=-15.7, mse=11.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.12it/s, epoch=5, loss=299, lmpl=-16.5, mse=9]
# 100%|██████████| 8/8 [00:01<00:00,  6.33it/s, epoch=6, loss=442, lmpl=-16.5, mse=9.28]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s, epoch=7, loss=234, lmpl=-16.4, mse=9.01]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s, epoch=8, loss=207, lmpl=-17.2, mse=10.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.35it/s, epoch=9, loss=265, lmpl=-15.8, mse=9.56]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s, epoch=10, loss=362, lmpl=-17.3, mse=12.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.29it/s, epoch=11, loss=344, lmpl=-15.7, mse=9.28]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s, epoch=12, loss=330, lmpl=-17.4, mse=11]
# 100%|██████████| 8/8 [00:01<00:00,  6.18it/s, epoch=13, loss=284, lmpl=-16.7, mse=8.72]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s, epoch=14, loss=236, lmpl=-18.2, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s, epoch=15, loss=269, lmpl=-17.9, mse=11.6]
# 100%|██████████| 8/8 [00:01<00:00,  6.16it/s, epoch=16, loss=247, lmpl=-17.1, mse=9.95]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s, epoch=17, loss=210, lmpl=-16.7, mse=9.21]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s, epoch=18, loss=254, lmpl=-18.5, mse=8.47]
# 100%|██████████| 8/8 [00:01<00:00,  5.90it/s, epoch=19, loss=197, lmpl=-16.2, mse=9.93]
# 100%|██████████| 8/8 [00:01<00:00,  5.94it/s, epoch=20, loss=270, lmpl=-18.3, mse=10.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.03it/s, epoch=21, loss=295, lmpl=-16.6, mse=9.79]
# 100%|██████████| 8/8 [00:01<00:00,  6.05it/s, epoch=22, loss=453, lmpl=-18.3, mse=11.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s, epoch=23, loss=305, lmpl=-18.3, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.07it/s, epoch=24, loss=341, lmpl=-16.8, mse=10.9]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s, epoch=25, loss=231, lmpl=-18, mse=11]
# 100%|██████████| 8/8 [00:01<00:00,  5.90it/s, epoch=26, loss=267, lmpl=-16.6, mse=12.6]
# 100%|██████████| 8/8 [00:01<00:00,  5.81it/s, epoch=27, loss=209, lmpl=-18.3, mse=11.6]
# 100%|██████████| 8/8 [00:01<00:00,  5.85it/s, epoch=28, loss=213, lmpl=-17, mse=8.93]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s, epoch=29, loss=289, lmpl=-16.9, mse=9.55]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s, epoch=30, loss=279, lmpl=-16.3, mse=10.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s, epoch=31, loss=230, lmpl=-17, mse=13.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.13it/s, epoch=32, loss=211, lmpl=-17.5, mse=11]
# 100%|██████████| 8/8 [00:01<00:00,  6.07it/s, epoch=33, loss=251, lmpl=-19.7, mse=13.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.18it/s, epoch=34, loss=273, lmpl=-17.7, mse=11.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.18it/s, epoch=35, loss=237, lmpl=-16.2, mse=10.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s, epoch=36, loss=283, lmpl=-16, mse=11.8]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s, epoch=37, loss=248, lmpl=-20.2, mse=11.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s, epoch=38, loss=206, lmpl=-15.8, mse=11]
# 100%|██████████| 8/8 [00:01<00:00,  6.20it/s, epoch=39, loss=246, lmpl=-18.9, mse=10.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s, epoch=40, loss=245, lmpl=-17.9, mse=8.66]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s, epoch=41, loss=267, lmpl=-15.6, mse=9.87]
# 100%|██████████| 8/8 [00:01<00:00,  5.97it/s, epoch=42, loss=304, lmpl=-18, mse=10.6]
# 100%|██████████| 8/8 [00:01<00:00,  5.73it/s, epoch=43, loss=182, lmpl=-15.4, mse=9.09]
# 100%|██████████| 8/8 [00:01<00:00,  5.91it/s, epoch=44, loss=282, lmpl=-15.7, mse=10.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.01it/s, epoch=45, loss=312, lmpl=-17.7, mse=11.9]
# 100%|██████████| 8/8 [00:01<00:00,  5.95it/s, epoch=46, loss=219, lmpl=-16.8, mse=9.47]
# 100%|██████████| 8/8 [00:01<00:00,  6.20it/s, epoch=47, loss=235, lmpl=-17.1, mse=12.8]
# 100%|██████████| 8/8 [00:01<00:00,  6.18it/s, epoch=48, loss=250, lmpl=-18, mse=11.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s, epoch=49, loss=256, lmpl=-17.5, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  5.65it/s, epoch=50, loss=241, lmpl=-17.6, mse=8.52]
# 100%|██████████| 8/8 [00:01<00:00,  5.78it/s, epoch=51, loss=314, lmpl=-16.4, mse=8.64]
# 100%|██████████| 8/8 [00:01<00:00,  5.93it/s, epoch=52, loss=292, lmpl=-15.2, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.06it/s, epoch=53, loss=281, lmpl=-16.8, mse=12]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s, epoch=54, loss=299, lmpl=-17.9, mse=9.46]
# 100%|██████████| 8/8 [00:01<00:00,  6.20it/s, epoch=55, loss=254, lmpl=-16.3, mse=11.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s, epoch=56, loss=208, lmpl=-17.4, mse=8.88]
# 100%|██████████| 8/8 [00:01<00:00,  5.69it/s, epoch=57, loss=204, lmpl=-16, mse=9.07]
# 100%|██████████| 8/8 [00:01<00:00,  5.60it/s, epoch=58, loss=186, lmpl=-17, mse=11.3]
# 100%|██████████| 8/8 [00:01<00:00,  5.46it/s, epoch=59, loss=331, lmpl=-15.8, mse=10.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.02it/s, epoch=60, loss=336, lmpl=-17.8, mse=11.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.14it/s, epoch=61, loss=256, lmpl=-17, mse=11.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s, epoch=62, loss=236, lmpl=-18.1, mse=8.34]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s, epoch=63, loss=202, lmpl=-15.5, mse=7.95]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s, epoch=64, loss=247, lmpl=-16.2, mse=9.38]
# 100%|██████████| 8/8 [00:01<00:00,  6.16it/s, epoch=65, loss=272, lmpl=-16.5, mse=9.52]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s, epoch=66, loss=255, lmpl=-19.6, mse=11.6]
# 100%|██████████| 8/8 [00:01<00:00,  6.29it/s, epoch=67, loss=275, lmpl=-16.7, mse=11.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s, epoch=68, loss=302, lmpl=-17.5, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.20it/s, epoch=69, loss=249, lmpl=-17.2, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s, epoch=70, loss=207, lmpl=-15.3, mse=8.46]
# 100%|██████████| 8/8 [00:01<00:00,  6.13it/s, epoch=71, loss=214, lmpl=-17, mse=8.63]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s, epoch=72, loss=221, lmpl=-17.4, mse=12.6]
# 100%|██████████| 8/8 [00:01<00:00,  6.02it/s, epoch=73, loss=290, lmpl=-16.9, mse=10.9]
# 100%|██████████| 8/8 [00:01<00:00,  5.99it/s, epoch=74, loss=235, lmpl=-17.3, mse=10.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.07it/s, epoch=75, loss=246, lmpl=-18.2, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.33it/s, epoch=76, loss=214, lmpl=-17.4, mse=10.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s, epoch=77, loss=265, lmpl=-18.2, mse=10.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.35it/s, epoch=78, loss=203, lmpl=-17.9, mse=12.6]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s, epoch=79, loss=202, lmpl=-17.2, mse=11.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s, epoch=80, loss=253, lmpl=-17.3, mse=9.99]
# 100%|██████████| 8/8 [00:01<00:00,  6.08it/s, epoch=81, loss=286, lmpl=-16, mse=11.5]
# 100%|██████████| 8/8 [00:01<00:00,  5.95it/s, epoch=82, loss=198, lmpl=-16.3, mse=12.6]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s, epoch=83, loss=257, lmpl=-16.3, mse=10.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s, epoch=84, loss=268, lmpl=-16.6, mse=9.16]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s, epoch=85, loss=261, lmpl=-17.5, mse=10.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s, epoch=86, loss=196, lmpl=-17.4, mse=11.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s, epoch=87, loss=257, lmpl=-15.5, mse=8.74]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s, epoch=88, loss=257, lmpl=-17.4, mse=9.83]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s, epoch=89, loss=260, lmpl=-17.3, mse=10.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s, epoch=90, loss=228, lmpl=-19.4, mse=10.6]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s, epoch=91, loss=283, lmpl=-19.3, mse=10.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.41it/s, epoch=92, loss=295, lmpl=-17.8, mse=9.65]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s, epoch=93, loss=230, lmpl=-16.5, mse=9.9]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s, epoch=94, loss=346, lmpl=-14.9, mse=11.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s, epoch=95, loss=216, lmpl=-18.7, mse=10.6]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s, epoch=96, loss=205, lmpl=-19.4, mse=10.3]
# 100%|██████████| 8/8 [00:01<00:00,  5.91it/s, epoch=97, loss=186, lmpl=-17, mse=10.9]
# 100%|██████████| 8/8 [00:01<00:00,  6.05it/s, epoch=98, loss=264, lmpl=-15.9, mse=11.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s, epoch=99, loss=198, lmpl=-17, mse=8.71]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s, epoch=100, loss=278, lmpl=-16.3, mse=10.8]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s, epoch=101, loss=199, lmpl=-16.3, mse=11.8]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s, epoch=102, loss=231, lmpl=-17.8, mse=12.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s, epoch=103, loss=305, lmpl=-17, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s, epoch=104, loss=219, lmpl=-18.4, mse=11.5]
# 100%|██████████| 8/8 [00:01<00:00,  5.79it/s, epoch=105, loss=347, lmpl=-17.7, mse=9.52]
# 100%|██████████| 8/8 [00:01<00:00,  6.06it/s, epoch=106, loss=246, lmpl=-17.3, mse=13.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s, epoch=107, loss=337, lmpl=-17.3, mse=9.11]
# 100%|██████████| 8/8 [00:01<00:00,  6.30it/s, epoch=108, loss=317, lmpl=-17.1, mse=10.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.35it/s, epoch=109, loss=395, lmpl=-18.8, mse=8.89]
# 100%|██████████| 8/8 [00:01<00:00,  6.30it/s, epoch=110, loss=234, lmpl=-17.7, mse=11.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.30it/s, epoch=111, loss=355, lmpl=-15.8, mse=9.97]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s, epoch=112, loss=181, lmpl=-18.5, mse=8.67]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s, epoch=113, loss=273, lmpl=-16.5, mse=8.62]
# 100%|██████████| 8/8 [00:01<00:00,  6.20it/s, epoch=114, loss=237, lmpl=-17.2, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s, epoch=115, loss=299, lmpl=-17.1, mse=12.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s, epoch=116, loss=264, lmpl=-17.1, mse=9.48]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s, epoch=117, loss=261, lmpl=-17.2, mse=9.94]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s, epoch=118, loss=324, lmpl=-16.6, mse=10.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s, epoch=119, loss=285, lmpl=-17.2, mse=10.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s, epoch=120, loss=188, lmpl=-18.9, mse=8.94]
# 100%|██████████| 8/8 [00:01<00:00,  5.82it/s, epoch=121, loss=274, lmpl=-16.9, mse=10.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s, epoch=122, loss=231, lmpl=-16.3, mse=9.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.13it/s, epoch=123, loss=206, lmpl=-16.9, mse=9.34]
# 100%|██████████| 8/8 [00:01<00:00,  6.05it/s, epoch=124, loss=210, lmpl=-17.6, mse=10.9]
# 100%|██████████| 8/8 [00:01<00:00,  6.30it/s, epoch=125, loss=237, lmpl=-15.1, mse=9.25]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s, epoch=126, loss=301, lmpl=-16.8, mse=10.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s, epoch=127, loss=292, lmpl=-16.3, mse=11.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.12it/s, epoch=128, loss=307, lmpl=-16.6, mse=9.78]
# 100%|██████████| 8/8 [00:01<00:00,  6.00it/s, epoch=129, loss=222, lmpl=-16.5, mse=11.9]
# 100%|██████████| 8/8 [00:01<00:00,  5.87it/s, epoch=130, loss=251, lmpl=-17.3, mse=11.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s, epoch=131, loss=261, lmpl=-15.9, mse=12.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s, epoch=132, loss=271, lmpl=-19, mse=10.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s, epoch=133, loss=221, lmpl=-15.9, mse=11.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s, epoch=134, loss=233, lmpl=-19.3, mse=13.6]
# 100%|██████████| 8/8 [00:01<00:00,  6.33it/s, epoch=135, loss=293, lmpl=-17, mse=10.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.30it/s, epoch=136, loss=195, lmpl=-16, mse=10.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s, epoch=137, loss=243, lmpl=-17.1, mse=10.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s, epoch=138, loss=231, lmpl=-16, mse=9.68]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s, epoch=139, loss=283, lmpl=-16.1, mse=10.8]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s, epoch=140, loss=220, lmpl=-17.7, mse=12.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.33it/s, epoch=141, loss=205, lmpl=-16.5, mse=12.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s, epoch=142, loss=292, lmpl=-16.7, mse=11.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s, epoch=143, loss=222, lmpl=-16.6, mse=10.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s, epoch=144, loss=295, lmpl=-17.2, mse=8.21]
# 100%|██████████| 8/8 [00:01<00:00,  6.05it/s, epoch=145, loss=278, lmpl=-17.7, mse=9.95]
# 100%|██████████| 8/8 [00:01<00:00,  5.88it/s, epoch=146, loss=320, lmpl=-16.2, mse=11.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s, epoch=147, loss=474, lmpl=-16.3, mse=7.57]
# 100%|██████████| 8/8 [00:01<00:00,  6.49it/s, epoch=148, loss=243, lmpl=-17.8, mse=10.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s, epoch=149, loss=279, lmpl=-15.8, mse=7.27]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s, epoch=150, loss=233, lmpl=-18.5, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s, epoch=151, loss=306, lmpl=-15.6, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.38it/s, epoch=152, loss=359, lmpl=-16.3, mse=11.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s, epoch=153, loss=237, lmpl=-16.5, mse=9.59]
# 100%|██████████| 8/8 [00:01<00:00,  6.12it/s, epoch=154, loss=246, lmpl=-17.9, mse=9.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s, epoch=155, loss=281, lmpl=-15.7, mse=9.89]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s, epoch=156, loss=234, lmpl=-16.3, mse=9.74]
# 100%|██████████| 8/8 [00:01<00:00,  6.46it/s, epoch=157, loss=235, lmpl=-15.6, mse=10.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.35it/s, epoch=158, loss=204, lmpl=-16.2, mse=10.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s, epoch=159, loss=275, lmpl=-16, mse=9.37]
# 100%|██████████| 8/8 [00:01<00:00,  6.38it/s, epoch=160, loss=258, lmpl=-14.5, mse=9.28]
# 100%|██████████| 8/8 [00:01<00:00,  6.10it/s, epoch=161, loss=227, lmpl=-16.5, mse=11]
# 100%|██████████| 8/8 [00:01<00:00,  6.41it/s, epoch=162, loss=277, lmpl=-17, mse=9.81]
# 100%|██████████| 8/8 [00:01<00:00,  6.44it/s, epoch=163, loss=258, lmpl=-16.1, mse=10.8]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s, epoch=164, loss=177, lmpl=-16.9, mse=12.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.37it/s, epoch=165, loss=258, lmpl=-16.1, mse=11.8]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s, epoch=166, loss=246, lmpl=-17.2, mse=9.45]
# 100%|██████████| 8/8 [00:01<00:00,  6.39it/s, epoch=167, loss=274, lmpl=-16.3, mse=10.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s, epoch=168, loss=282, lmpl=-16, mse=10.3]
# 100%|██████████| 8/8 [00:01<00:00,  6.14it/s, epoch=169, loss=389, lmpl=-17.1, mse=8.4]
# 100%|██████████| 8/8 [00:01<00:00,  6.16it/s, epoch=170, loss=229, lmpl=-15.4, mse=9.6]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s, epoch=171, loss=199, lmpl=-15.9, mse=9.49]
# 100%|██████████| 8/8 [00:01<00:00,  6.39it/s, epoch=172, loss=241, lmpl=-16.2, mse=8.89]
# 100%|██████████| 8/8 [00:01<00:00,  6.48it/s, epoch=173, loss=410, lmpl=-16.2, mse=9.24]
# 100%|██████████| 8/8 [00:01<00:00,  6.44it/s, epoch=174, loss=264, lmpl=-16.8, mse=9.87]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s, epoch=175, loss=290, lmpl=-17.5, mse=10.9]
# 100%|██████████| 8/8 [00:01<00:00,  6.37it/s, epoch=176, loss=361, lmpl=-18.8, mse=9.61]
# 100%|██████████| 8/8 [00:01<00:00,  6.12it/s, epoch=177, loss=279, lmpl=-16.3, mse=10.7]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s, epoch=178, loss=190, lmpl=-16.3, mse=10.9]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s, epoch=179, loss=184, lmpl=-16.3, mse=9.85]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s, epoch=180, loss=345, lmpl=-15.3, mse=9.84]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s, epoch=181, loss=328, lmpl=-16.2, mse=9.91]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s, epoch=182, loss=270, lmpl=-16.9, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.41it/s, epoch=183, loss=240, lmpl=-16.6, mse=11.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s, epoch=184, loss=242, lmpl=-16.6, mse=10.2]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s, epoch=185, loss=263, lmpl=-16.3, mse=8.46]
# 100%|██████████| 8/8 [00:01<00:00,  6.06it/s, epoch=186, loss=253, lmpl=-16.3, mse=9.51]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s, epoch=187, loss=237, lmpl=-17.9, mse=9.17]
# 100%|██████████| 8/8 [00:01<00:00,  6.44it/s, epoch=188, loss=214, lmpl=-15.8, mse=8.31]
# 100%|██████████| 8/8 [00:01<00:00,  6.40it/s, epoch=189, loss=217, lmpl=-17.2, mse=10.1]
# 100%|██████████| 8/8 [00:01<00:00,  6.46it/s, epoch=190, loss=277, lmpl=-16.1, mse=9.51]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s, epoch=191, loss=514, lmpl=-17.6, mse=9.48]
# 100%|██████████| 8/8 [00:01<00:00,  6.45it/s, epoch=192, loss=228, lmpl=-18, mse=9.86]
# 100%|██████████| 8/8 [00:01<00:00,  6.16it/s, epoch=193, loss=269, lmpl=-16.7, mse=10.5]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s, epoch=194, loss=221, lmpl=-15.6, mse=7.56]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s, epoch=195, loss=285, lmpl=-16.6, mse=9.23]
# 100%|██████████| 8/8 [00:01<00:00,  6.29it/s, epoch=196, loss=252, lmpl=-15, mse=8.83]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s, epoch=197, loss=231, lmpl=-16.2, mse=8.67]
# 100%|██████████| 8/8 [00:01<00:00,  6.38it/s, epoch=198, loss=261, lmpl=-16.5, mse=8.74]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s, epoch=199, loss=265, lmpl=-16.2, mse=8.23]

# %%
# rounds = 10

# for r in range(rounds):
#     if r % 2 == 0:
#         model.freeze_decoder()
#         model.unfreeze_cdvi()
#         print("TRAINING CDVI")
#     else:
#         model.unfreeze_decoder()
#         model.freeze_cdvi()
#         print("TRAINING DECODER")

#     num_epochs = 200
#     losses = trainer.train(
#         num_epochs=num_epochs,
#         max_clip_norm=cfg.training.max_clip_norm,
#         alpha=None,
#         validate=False,
#     )

# %%
from dviforbml.evaluation.visualization.visualize_dvinp import visualize_ddsnp


max_context_size = 5
num_samples = 1600  # num_cells will be root

ranges = [(-6, 6), (-6, 6)]

targets, samples = visualize_ddsnp(
    device=device,
    dvinp=model,
    dataloader=test_loader,
    num_samples=num_samples,
    max_context_size=max_context_size,
    ranges=ranges,
)

# %%
from dviforbml.components.cdvi.cmcd import CMCD
from dviforbml.components.cdvi.ula import ULA
from dviforbml.components.control.aggr_control import AggrControl
from dviforbml.components.schedule.annealing_schedule import AggrAnnealingSchedule
from dviforbml.components.schedule.free_noise_schedule import AggrFreeNoiseSchedule

annealing_schedule = AggrAnnealingSchedule(
    z_dim=cfg.model.z_dim,
    h_dim=cfg.model.h_dim,
    non_linearity=cfg.model.non_linearity,
    num_steps=cfg.model.num_steps,
    max_context_size=cfg.model.max_context_size,
    device=device,
)

noise_schedule = AggrFreeNoiseSchedule(
    z_dim=cfg.model.z_dim,
    h_dim=cfg.model.h_dim,
    num_steps=cfg.model.num_steps,
    num_layers=cfg.model.num_layers_sched,
    non_linearity=cfg.model.non_linearity,
    max_context_size=cfg.model.max_context_size,
    device=device,
)

control = AggrControl(
    h_dim=cfg.model.h_dim,
    z_dim=cfg.model.z_dim,
    num_steps=cfg.model.num_steps,
    num_layers=cfg.model.num_layers_ctrl,
    non_linearity=cfg.model.non_linearity,
    max_context_size=cfg.model.max_context_size,
    use_score=False,
)

model.cdvi = CMCD(
    z_dim=cfg.model.z_dim,
    num_steps=cfg.model.num_steps,
    control=control,
    step_size_schedule=model.cdvi.step_size_schedule,
    noise_schedule=noise_schedule,
    annealing_schedule=annealing_schedule,
    device=device,
)


model.freeze_decoder()
# model.freeze_encoder()

# %%
from dataclasses import dataclass

import torch
import wandb
from torch.utils.data import DataLoader

from dviforbml.architectures.dvi import DVI
from dviforbml.components.control.aggr_control import AggrControl
from dviforbml.components.control.bca_control import BCAControl
from dviforbml.components.control.mhca_control import MHCAControl
from dviforbml.components.encoder.aggr_encoder import Aggr, AggrEncoder
from dviforbml.components.encoder.bca_encoder import BCAEncoder
from dviforbml.components.encoder.mhca_encoder import MHCAEncoder
from dviforbml.utils.datasets import ContextSetDataset
from dviforbml.utils.distros import TaskPosteriorGMM
from dviforbml.components.cdvi.dds import DDS
from dviforbml.training.dds_trainer import DDSTrainerContext
from dviforbml.evaluation.visualization.visualize_dvi import visualize_dds_2d

# %%
try:
    import torch_directml

    device = torch_directml.device()
except ImportError:
    device = torch.device("cpu")

device = torch.device("cpu")

# %%
@dataclass
class Config:
    num_steps = 16
    c_dim = 2
    z_dim = 2
    h_dim = 32
    num_layers = 6
    non_linearity = "ReLU"
    num_heads_sa = None  # 8
    num_heads_ca = 4
    use_score = False
    learning_rate = 3e-4
    size = 64
    batch_size = 64
    max_context_size = None


cfg = Config()

# %%
dataset = ContextSetDataset(
    size=cfg.size,
    c_dim=cfg.c_dim,
    max_context_size=10,
    sampling_factor=4,
)

dataloader = DataLoader(dataset=dataset, batch_size=cfg.batch_size, shuffle=True)

# %%
contextual_target = TaskPosteriorGMM

aggr_encoder = AggrEncoder(
    c_dim=cfg.c_dim,
    h_dim=cfg.h_dim,
    z_dim=cfg.z_dim,
    num_layers=cfg.num_layers,
    non_linearity=cfg.non_linearity,
    num_heads=cfg.num_heads_sa,
    num_blocks=1,
    max_context_size=cfg.max_context_size,
    aggregation=Aggr.MEAN,
)

bca_encoder = BCAEncoder(
    c_dim=cfg.c_dim,
    h_dim=cfg.h_dim,
    z_dim=cfg.z_dim,
    num_layers=cfg.num_layers,
    non_linearity=cfg.non_linearity,
    num_heads=cfg.num_heads_sa,
    num_blocks=1,
    max_context_size=cfg.max_context_size,
    bca_dim=cfg.h_dim,
)

mhca_encoder = MHCAEncoder(
    z_dim=cfg.z_dim,
    c_dim=cfg.c_dim,
    h_dim=cfg.h_dim,
    num_layers=cfg.num_layers,
    non_linearity=cfg.non_linearity,
    num_heads=cfg.num_heads_sa,
    num_blocks=1,
    max_context_size=cfg.max_context_size,
)

aggr_control = AggrControl(
    h_dim=cfg.h_dim,
    z_dim=cfg.z_dim,
    num_steps=cfg.num_steps,
    num_layers=cfg.num_layers,
    non_linearity=cfg.non_linearity,
    max_context_size=cfg.max_context_size,
    use_score=cfg.use_score,
)

bca_control = BCAControl(
    h_dim=cfg.h_dim,
    z_dim=cfg.z_dim,
    num_steps=cfg.num_steps,
    num_layers=cfg.num_layers,
    non_linearity=cfg.non_linearity,
    max_context_size=cfg.max_context_size,
    use_score=cfg.use_score,
)

mhca_control = MHCAControl(
    h_dim=cfg.h_dim,
    z_dim=cfg.z_dim,
    num_steps=cfg.num_steps,
    num_layers=cfg.num_layers,
    non_linearity=cfg.non_linearity,
    max_context_size=cfg.max_context_size,
    use_score=cfg.use_score,
    num_heads=cfg.num_heads_ca,
)

comps = (
    aggr_encoder,
    aggr_control,
)

# comps = (
#     bca_encoder,
#     bca_control,
# )

# comps = (
#     mhca_encoder,
#     mhca_control,
# )

cdvi = DDS(
    z_dim=cfg.z_dim,
    num_steps=cfg.num_steps,
    control=comps[1],
    meta_batch_size=cfg.batch_size,
    num_subtasks=1,
    device=device,
)

model = DVI(encoder=comps[0], cdvi=cdvi, contextual_target=contextual_target).to(device)

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.learning_rate)

trainer = DDSTrainerContext(
    model=model,
    device=device,
    dataset=dataset,
    train_loader=dataloader,
    val_loader=dataloader,
    optimizer=optimizer,
    scheduler=None,
    generator=torch.Generator(device=device),
    wandb_logging=False,
    num_subtasks=32,
    num_samples=32,
    val_grad_off=True,
)

print(model)
# Out:
# DVI(
#   (encoder): AggrEncoder(
#     (proj_in): Linear(in_features=2, out_features=32, bias=True)
#     (blocks): ModuleList(
#       (0): EncoderBlock(
#         (mlp): Sequential(
#           (0): Linear(in_features=32, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=32, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=32, out_features=32, bias=True)
#           (5): ReLU()
#           (6): Linear(in_features=32, out_features=32, bias=True)
#           (7): ReLU()
#           (8): Linear(in_features=32, out_features=32, bias=True)
#           (9): ReLU()
#           (10): Linear(in_features=32, out_features=32, bias=True)
#           (11): ReLU()
#           (12): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#     )
#   )
#   (cdvi): DDS(
#     (control): AggrControl(
#       (proj_n): Embedding(17, 2)
#       (mlp): Sequential(
#         (0): Linear(in_features=36, out_features=32, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=32, out_features=32, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=32, out_features=32, bias=True)
#         (5): ReLU()
#         (6): Linear(in_features=32, out_features=32, bias=True)
#         (7): ReLU()
#         (8): Linear(in_features=32, out_features=32, bias=True)
#         (9): ReLU()
#         (10): Linear(in_features=32, out_features=32, bias=True)
#         (11): ReLU()
#         (12): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (proj_out): Linear(in_features=32, out_features=2, bias=True)
#     )
#   )
# )

# %%
trainer.wandb_logging = False
if trainer.wandb_logging:
    wandb.init(project="local-toytaskposterior", name="mhca")

# %%
# trainer.optimizer.param_groups[0]["lr"] = 0.1 * cfg.learning_rate
num_epochs = 500
trainer.train(num_epochs=num_epochs, max_clip_norm=None, alpha=None)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 11.46it/s, epoch=0, loss=86.2]
# 100%|██████████| 1/1 [00:00<00:00, 11.31it/s, epoch=1, loss=80.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.12it/s, epoch=2, loss=57.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.15it/s, epoch=3, loss=93.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.96it/s, epoch=4, loss=110]
# 100%|██████████| 1/1 [00:00<00:00, 13.05it/s, epoch=5, loss=84.5]
# 100%|██████████| 1/1 [00:00<00:00, 12.98it/s, epoch=6, loss=71.3]
# 100%|██████████| 1/1 [00:00<00:00, 12.94it/s, epoch=7, loss=74.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.96it/s, epoch=8, loss=71.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.49it/s, epoch=9, loss=84.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.01it/s, epoch=10, loss=101]
# 100%|██████████| 1/1 [00:00<00:00, 13.34it/s, epoch=11, loss=89.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.37it/s, epoch=12, loss=80.1]
# 100%|██████████| 1/1 [00:00<00:00, 15.68it/s, epoch=13, loss=77.4]
# 100%|██████████| 1/1 [00:00<00:00, 15.97it/s, epoch=14, loss=81.4]
# 100%|██████████| 1/1 [00:00<00:00, 16.44it/s, epoch=15, loss=77.1]
# 100%|██████████| 1/1 [00:00<00:00, 15.22it/s, epoch=16, loss=93.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.60it/s, epoch=17, loss=71.2]
# 100%|██████████| 1/1 [00:00<00:00, 12.99it/s, epoch=18, loss=78.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.89it/s, epoch=19, loss=90.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.38it/s, epoch=20, loss=83.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.50it/s, epoch=21, loss=57.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.11it/s, epoch=22, loss=88.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.22it/s, epoch=23, loss=51.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.81it/s, epoch=24, loss=80.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.35it/s, epoch=25, loss=89.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.47it/s, epoch=26, loss=70.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.66it/s, epoch=27, loss=58.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.48it/s, epoch=28, loss=61.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.61it/s, epoch=29, loss=81.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.67it/s, epoch=30, loss=68.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.79it/s, epoch=31, loss=98.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.56it/s, epoch=32, loss=72.6]
# 100%|██████████| 1/1 [00:00<00:00, 12.98it/s, epoch=33, loss=81.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.14it/s, epoch=34, loss=81.5]
# 100%|██████████| 1/1 [00:00<00:00, 16.27it/s, epoch=35, loss=64.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.69it/s, epoch=36, loss=71.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.17it/s, epoch=37, loss=85.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.91it/s, epoch=38, loss=88.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.19it/s, epoch=39, loss=76.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.20it/s, epoch=40, loss=89.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.86it/s, epoch=41, loss=74.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.95it/s, epoch=42, loss=67.9]
# 100%|██████████| 1/1 [00:00<00:00, 12.81it/s, epoch=43, loss=112]
# 100%|██████████| 1/1 [00:00<00:00, 14.08it/s, epoch=44, loss=71.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.73it/s, epoch=45, loss=68.6]
# 100%|██████████| 1/1 [00:00<00:00, 15.32it/s, epoch=46, loss=84.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.22it/s, epoch=47, loss=71]
# 100%|██████████| 1/1 [00:00<00:00, 12.86it/s, epoch=48, loss=104]
# 100%|██████████| 1/1 [00:00<00:00, 14.59it/s, epoch=49, loss=90.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.33it/s, epoch=50, loss=97.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.43it/s, epoch=51, loss=91.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.30it/s, epoch=52, loss=72.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.94it/s, epoch=53, loss=73.5]
# 100%|██████████| 1/1 [00:00<00:00, 12.60it/s, epoch=54, loss=81.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.44it/s, epoch=55, loss=82.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.24it/s, epoch=56, loss=62.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.98it/s, epoch=57, loss=67.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.74it/s, epoch=58, loss=68.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.64it/s, epoch=59, loss=49.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.82it/s, epoch=60, loss=72.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.22it/s, epoch=61, loss=50]
# 100%|██████████| 1/1 [00:00<00:00, 13.85it/s, epoch=62, loss=83.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.55it/s, epoch=63, loss=99.5]
# 100%|██████████| 1/1 [00:00<00:00, 12.88it/s, epoch=64, loss=71.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.37it/s, epoch=65, loss=79.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.84it/s, epoch=66, loss=98.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.20it/s, epoch=67, loss=87.8]
# 100%|██████████| 1/1 [00:00<00:00, 10.75it/s, epoch=68, loss=92]
# 100%|██████████| 1/1 [00:00<00:00, 13.88it/s, epoch=69, loss=81.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.79it/s, epoch=70, loss=90.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.31it/s, epoch=71, loss=62.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.10it/s, epoch=72, loss=58.1]
# 100%|██████████| 1/1 [00:00<00:00, 13.52it/s, epoch=73, loss=58.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.31it/s, epoch=74, loss=80.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.63it/s, epoch=75, loss=73.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.50it/s, epoch=76, loss=86]
# 100%|██████████| 1/1 [00:00<00:00, 13.03it/s, epoch=77, loss=38.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.96it/s, epoch=78, loss=79.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.15it/s, epoch=79, loss=82.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.54it/s, epoch=80, loss=74.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.11it/s, epoch=81, loss=57.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.35it/s, epoch=82, loss=102]
# 100%|██████████| 1/1 [00:00<00:00, 15.22it/s, epoch=83, loss=94.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.72it/s, epoch=84, loss=91.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.28it/s, epoch=85, loss=85.8]
# 100%|██████████| 1/1 [00:00<00:00, 12.52it/s, epoch=86, loss=108]
# 100%|██████████| 1/1 [00:00<00:00, 14.70it/s, epoch=87, loss=81.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.28it/s, epoch=88, loss=69.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.58it/s, epoch=89, loss=69.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.09it/s, epoch=90, loss=94.3]
# 100%|██████████| 1/1 [00:00<00:00, 12.67it/s, epoch=91, loss=90.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.57it/s, epoch=92, loss=73.5]
# 100%|██████████| 1/1 [00:00<00:00, 15.91it/s, epoch=93, loss=75.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.33it/s, epoch=94, loss=72.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.54it/s, epoch=95, loss=69.6]
# 100%|██████████| 1/1 [00:00<00:00, 15.40it/s, epoch=96, loss=54.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.55it/s, epoch=97, loss=72.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.66it/s, epoch=98, loss=87.3]
# 100%|██████████| 1/1 [00:00<00:00, 12.68it/s, epoch=99, loss=91.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.61it/s, epoch=100, loss=83.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.67it/s, epoch=101, loss=80.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.71it/s, epoch=102, loss=63.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.59it/s, epoch=103, loss=77.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.32it/s, epoch=104, loss=93.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.01it/s, epoch=105, loss=73.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.16it/s, epoch=106, loss=71.9]
# 100%|██████████| 1/1 [00:00<00:00, 15.77it/s, epoch=107, loss=54]
# 100%|██████████| 1/1 [00:00<00:00, 15.20it/s, epoch=108, loss=72]
# 100%|██████████| 1/1 [00:00<00:00, 13.27it/s, epoch=109, loss=68.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.21it/s, epoch=110, loss=86.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.08it/s, epoch=111, loss=71.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.52it/s, epoch=112, loss=86]
# 100%|██████████| 1/1 [00:00<00:00, 14.89it/s, epoch=113, loss=63.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.80it/s, epoch=114, loss=64.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.66it/s, epoch=115, loss=70.3]
# 100%|██████████| 1/1 [00:00<00:00, 12.63it/s, epoch=116, loss=68]
# 100%|██████████| 1/1 [00:00<00:00, 14.13it/s, epoch=117, loss=79.3]
# 100%|██████████| 1/1 [00:00<00:00, 12.92it/s, epoch=118, loss=75.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.45it/s, epoch=119, loss=63.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.71it/s, epoch=120, loss=86.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.40it/s, epoch=121, loss=65.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.16it/s, epoch=122, loss=59.1]
# 100%|██████████| 1/1 [00:00<00:00, 13.95it/s, epoch=123, loss=62.9]
# 100%|██████████| 1/1 [00:00<00:00, 12.60it/s, epoch=124, loss=62.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.05it/s, epoch=125, loss=91]
# 100%|██████████| 1/1 [00:00<00:00, 14.66it/s, epoch=126, loss=46]
# 100%|██████████| 1/1 [00:00<00:00, 14.67it/s, epoch=127, loss=78.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.65it/s, epoch=128, loss=64]
# 100%|██████████| 1/1 [00:00<00:00, 13.61it/s, epoch=129, loss=75.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.42it/s, epoch=130, loss=77.9]
# 100%|██████████| 1/1 [00:00<00:00, 12.54it/s, epoch=131, loss=82.5]
# 100%|██████████| 1/1 [00:00<00:00, 11.82it/s, epoch=132, loss=57.5]
# 100%|██████████| 1/1 [00:00<00:00, 11.84it/s, epoch=133, loss=67]
# 100%|██████████| 1/1 [00:00<00:00, 14.27it/s, epoch=134, loss=65.2]
# 100%|██████████| 1/1 [00:00<00:00, 15.02it/s, epoch=135, loss=75.7]
# 100%|██████████| 1/1 [00:00<00:00, 11.12it/s, epoch=136, loss=66.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.58it/s, epoch=137, loss=74.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.76it/s, epoch=138, loss=72.1]
# 100%|██████████| 1/1 [00:00<00:00, 15.91it/s, epoch=139, loss=66.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.75it/s, epoch=140, loss=75.6]
# 100%|██████████| 1/1 [00:00<00:00, 12.98it/s, epoch=141, loss=54.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.78it/s, epoch=142, loss=78.6]
# 100%|██████████| 1/1 [00:00<00:00, 15.17it/s, epoch=143, loss=66.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.16it/s, epoch=144, loss=66.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.59it/s, epoch=145, loss=65]
# 100%|██████████| 1/1 [00:00<00:00, 14.27it/s, epoch=146, loss=65.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.84it/s, epoch=147, loss=77.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.49it/s, epoch=148, loss=72.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.43it/s, epoch=149, loss=77.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.74it/s, epoch=150, loss=63]
# 100%|██████████| 1/1 [00:00<00:00, 15.38it/s, epoch=151, loss=77.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.37it/s, epoch=152, loss=50.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.06it/s, epoch=153, loss=55.8]
# 100%|██████████| 1/1 [00:00<00:00, 15.13it/s, epoch=154, loss=59.4]
# 100%|██████████| 1/1 [00:00<00:00, 16.06it/s, epoch=155, loss=61.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.75it/s, epoch=156, loss=58.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.24it/s, epoch=157, loss=86.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.55it/s, epoch=158, loss=63.2]
# 100%|██████████| 1/1 [00:00<00:00, 15.03it/s, epoch=159, loss=68.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.71it/s, epoch=160, loss=53.7]
# 100%|██████████| 1/1 [00:00<00:00, 16.59it/s, epoch=161, loss=48.4]
# 100%|██████████| 1/1 [00:00<00:00, 15.97it/s, epoch=162, loss=82.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.65it/s, epoch=163, loss=60.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.79it/s, epoch=164, loss=47.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.52it/s, epoch=165, loss=59.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.48it/s, epoch=166, loss=45.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.34it/s, epoch=167, loss=81]
# 100%|██████████| 1/1 [00:00<00:00, 15.00it/s, epoch=168, loss=73.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.90it/s, epoch=169, loss=62.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.37it/s, epoch=170, loss=90.1]
# 100%|██████████| 1/1 [00:00<00:00, 16.71it/s, epoch=171, loss=77.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.68it/s, epoch=172, loss=60.8]
# 100%|██████████| 1/1 [00:00<00:00, 15.49it/s, epoch=173, loss=43.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.23it/s, epoch=174, loss=60.8]
# 100%|██████████| 1/1 [00:00<00:00, 15.16it/s, epoch=175, loss=68.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.11it/s, epoch=176, loss=67.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.89it/s, epoch=177, loss=67.5]
# 100%|██████████| 1/1 [00:00<00:00, 12.81it/s, epoch=178, loss=55.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.76it/s, epoch=179, loss=61.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.63it/s, epoch=180, loss=71.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.75it/s, epoch=181, loss=69.2]
# 100%|██████████| 1/1 [00:00<00:00, 15.49it/s, epoch=182, loss=62.8]
# 100%|██████████| 1/1 [00:00<00:00, 15.03it/s, epoch=183, loss=71.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.47it/s, epoch=184, loss=62.5]
# 100%|██████████| 1/1 [00:00<00:00, 12.95it/s, epoch=185, loss=53]
# 100%|██████████| 1/1 [00:00<00:00, 13.00it/s, epoch=186, loss=78.1]
# 100%|██████████| 1/1 [00:00<00:00, 10.48it/s, epoch=187, loss=58.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.99it/s, epoch=188, loss=49.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.70it/s, epoch=189, loss=52.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.18it/s, epoch=190, loss=71.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.21it/s, epoch=191, loss=70.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.49it/s, epoch=192, loss=64.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.25it/s, epoch=193, loss=48.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.49it/s, epoch=194, loss=45.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.70it/s, epoch=195, loss=55.2]
# 100%|██████████| 1/1 [00:00<00:00, 15.12it/s, epoch=196, loss=69.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.12it/s, epoch=197, loss=56.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.60it/s, epoch=198, loss=48.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.37it/s, epoch=199, loss=49.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.29it/s, epoch=200, loss=50]
# 100%|██████████| 1/1 [00:00<00:00, 16.02it/s, epoch=201, loss=63.8]
# 100%|██████████| 1/1 [00:00<00:00, 15.19it/s, epoch=202, loss=70.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.35it/s, epoch=203, loss=55.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.85it/s, epoch=204, loss=51]
# 100%|██████████| 1/1 [00:00<00:00, 12.92it/s, epoch=205, loss=47]
# 100%|██████████| 1/1 [00:00<00:00, 14.28it/s, epoch=206, loss=57.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.31it/s, epoch=207, loss=48.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.29it/s, epoch=208, loss=53.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.89it/s, epoch=209, loss=64.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.76it/s, epoch=210, loss=91.1]
# 100%|██████████| 1/1 [00:00<00:00, 13.39it/s, epoch=211, loss=47.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.45it/s, epoch=212, loss=56]
# 100%|██████████| 1/1 [00:00<00:00, 13.49it/s, epoch=213, loss=37.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.73it/s, epoch=214, loss=62.2]
# 100%|██████████| 1/1 [00:00<00:00, 12.00it/s, epoch=215, loss=54.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.96it/s, epoch=216, loss=48.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.70it/s, epoch=217, loss=53.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.39it/s, epoch=218, loss=54.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.34it/s, epoch=219, loss=60.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.27it/s, epoch=220, loss=98.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.37it/s, epoch=221, loss=53.9]
# 100%|██████████| 1/1 [00:00<00:00, 15.64it/s, epoch=222, loss=55.1]
# 100%|██████████| 1/1 [00:00<00:00, 15.75it/s, epoch=223, loss=41.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.48it/s, epoch=224, loss=40.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.42it/s, epoch=225, loss=43.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.81it/s, epoch=226, loss=64.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.80it/s, epoch=227, loss=57.9]
# 100%|██████████| 1/1 [00:00<00:00, 15.38it/s, epoch=228, loss=51.3]
# 100%|██████████| 1/1 [00:00<00:00, 12.92it/s, epoch=229, loss=59.2]
# 100%|██████████| 1/1 [00:00<00:00, 11.44it/s, epoch=230, loss=56.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.24it/s, epoch=231, loss=55.9]
# 100%|██████████| 1/1 [00:00<00:00, 15.13it/s, epoch=232, loss=53.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.20it/s, epoch=233, loss=48.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.03it/s, epoch=234, loss=44]
# 100%|██████████| 1/1 [00:00<00:00, 15.55it/s, epoch=235, loss=62.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.20it/s, epoch=236, loss=55.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.48it/s, epoch=237, loss=87.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.68it/s, epoch=238, loss=43.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.57it/s, epoch=239, loss=47.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.47it/s, epoch=240, loss=48.5]
# 100%|██████████| 1/1 [00:00<00:00, 15.52it/s, epoch=241, loss=74.6]
# 100%|██████████| 1/1 [00:00<00:00, 15.79it/s, epoch=242, loss=46.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.13it/s, epoch=243, loss=54.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.00it/s, epoch=244, loss=53.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.52it/s, epoch=245, loss=41.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.27it/s, epoch=246, loss=90.1]
# 100%|██████████| 1/1 [00:00<00:00, 15.96it/s, epoch=247, loss=49.8]
# 100%|██████████| 1/1 [00:00<00:00, 12.97it/s, epoch=248, loss=47.7]
# 100%|██████████| 1/1 [00:00<00:00, 12.51it/s, epoch=249, loss=50.9]
# 100%|██████████| 1/1 [00:00<00:00, 12.42it/s, epoch=250, loss=94.6]
# 100%|██████████| 1/1 [00:00<00:00, 12.50it/s, epoch=251, loss=56.4]
# 100%|██████████| 1/1 [00:00<00:00, 12.70it/s, epoch=252, loss=49.2]
# 100%|██████████| 1/1 [00:00<00:00, 12.49it/s, epoch=253, loss=46]
# 100%|██████████| 1/1 [00:00<00:00, 12.86it/s, epoch=254, loss=74.7]
# 100%|██████████| 1/1 [00:00<00:00, 12.03it/s, epoch=255, loss=53.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.28it/s, epoch=256, loss=36]
# 100%|██████████| 1/1 [00:00<00:00, 12.87it/s, epoch=257, loss=31.3]
# 100%|██████████| 1/1 [00:00<00:00, 12.35it/s, epoch=258, loss=47.1]
# 100%|██████████| 1/1 [00:00<00:00,  8.58it/s, epoch=259, loss=60]
# 100%|██████████| 1/1 [00:00<00:00, 11.56it/s, epoch=260, loss=39.3]
# 100%|██████████| 1/1 [00:00<00:00, 12.14it/s, epoch=261, loss=60]
# 100%|██████████| 1/1 [00:00<00:00, 12.29it/s, epoch=262, loss=55.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.21it/s, epoch=263, loss=37.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.09it/s, epoch=264, loss=61.7]
# 100%|██████████| 1/1 [00:00<00:00, 11.63it/s, epoch=265, loss=59.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.04it/s, epoch=266, loss=58.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.91it/s, epoch=267, loss=59.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.18it/s, epoch=268, loss=51.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.71it/s, epoch=269, loss=79.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.66it/s, epoch=270, loss=49.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.12it/s, epoch=271, loss=29.6]
# 100%|██████████| 1/1 [00:00<00:00, 12.76it/s, epoch=272, loss=53.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.58it/s, epoch=273, loss=38.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.98it/s, epoch=274, loss=51]
# 100%|██████████| 1/1 [00:00<00:00, 13.44it/s, epoch=275, loss=52.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.88it/s, epoch=276, loss=64.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.75it/s, epoch=277, loss=54.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.04it/s, epoch=278, loss=55.8]
# 100%|██████████| 1/1 [00:00<00:00, 12.74it/s, epoch=279, loss=40.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.91it/s, epoch=280, loss=60.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.39it/s, epoch=281, loss=50.4]
# 100%|██████████| 1/1 [00:00<00:00, 15.77it/s, epoch=282, loss=43.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.41it/s, epoch=283, loss=52.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.60it/s, epoch=284, loss=62.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.65it/s, epoch=285, loss=57.9]
# 100%|██████████| 1/1 [00:00<00:00, 12.97it/s, epoch=286, loss=47.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.12it/s, epoch=287, loss=48.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.50it/s, epoch=288, loss=64]
# 100%|██████████| 1/1 [00:00<00:00, 14.29it/s, epoch=289, loss=44.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.08it/s, epoch=290, loss=56.1]
# 100%|██████████| 1/1 [00:00<00:00, 15.52it/s, epoch=291, loss=40.5]
# 100%|██████████| 1/1 [00:00<00:00, 15.63it/s, epoch=292, loss=30.4]
# 100%|██████████| 1/1 [00:00<00:00, 15.95it/s, epoch=293, loss=29.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.07it/s, epoch=294, loss=41.9]
# 100%|██████████| 1/1 [00:00<00:00, 16.22it/s, epoch=295, loss=46.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.37it/s, epoch=296, loss=38.3]
# 100%|██████████| 1/1 [00:00<00:00, 10.96it/s, epoch=297, loss=38.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.86it/s, epoch=298, loss=39.1]
# 100%|██████████| 1/1 [00:00<00:00, 13.23it/s, epoch=299, loss=76.4]
# 100%|██████████| 1/1 [00:00<00:00, 16.05it/s, epoch=300, loss=54.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.98it/s, epoch=301, loss=61.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.14it/s, epoch=302, loss=28.1]
# 100%|██████████| 1/1 [00:00<00:00, 13.59it/s, epoch=303, loss=49.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.38it/s, epoch=304, loss=57.8]
# 100%|██████████| 1/1 [00:00<00:00, 15.37it/s, epoch=305, loss=72.8]
# 100%|██████████| 1/1 [00:00<00:00, 15.67it/s, epoch=306, loss=49.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.86it/s, epoch=307, loss=62.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.70it/s, epoch=308, loss=41.5]
# 100%|██████████| 1/1 [00:00<00:00, 15.63it/s, epoch=309, loss=46.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.45it/s, epoch=310, loss=52.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.93it/s, epoch=311, loss=47.7]
# 100%|██████████| 1/1 [00:00<00:00, 12.19it/s, epoch=312, loss=37.6]
# 100%|██████████| 1/1 [00:00<00:00, 12.77it/s, epoch=313, loss=54.5]
# 100%|██████████| 1/1 [00:00<00:00, 11.57it/s, epoch=314, loss=48.4]
# 100%|██████████| 1/1 [00:00<00:00, 11.88it/s, epoch=315, loss=55.8]
# 100%|██████████| 1/1 [00:00<00:00, 10.72it/s, epoch=316, loss=61.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.24it/s, epoch=317, loss=67.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.68it/s, epoch=318, loss=45.6]
# 100%|██████████| 1/1 [00:00<00:00, 11.35it/s, epoch=319, loss=53.5]
# 100%|██████████| 1/1 [00:00<00:00, 11.79it/s, epoch=320, loss=50.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.91it/s, epoch=321, loss=53]
# 100%|██████████| 1/1 [00:00<00:00, 12.82it/s, epoch=322, loss=98.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.09it/s, epoch=323, loss=33.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.20it/s, epoch=324, loss=50.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.63it/s, epoch=325, loss=59.9]
# 100%|██████████| 1/1 [00:00<00:00, 16.14it/s, epoch=326, loss=64.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.00it/s, epoch=327, loss=46.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.07it/s, epoch=328, loss=49.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.34it/s, epoch=329, loss=58.3]
# 100%|██████████| 1/1 [00:00<00:00, 13.03it/s, epoch=330, loss=40.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.67it/s, epoch=331, loss=71.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.33it/s, epoch=332, loss=46.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.45it/s, epoch=333, loss=49.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.03it/s, epoch=334, loss=65.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.26it/s, epoch=335, loss=48.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.22it/s, epoch=336, loss=50.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.82it/s, epoch=337, loss=80.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.85it/s, epoch=338, loss=39.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.75it/s, epoch=339, loss=48.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.94it/s, epoch=340, loss=47.6]
# 100%|██████████| 1/1 [00:00<00:00, 12.13it/s, epoch=341, loss=38.4]
# 100%|██████████| 1/1 [00:00<00:00, 12.39it/s, epoch=342, loss=71]
# 100%|██████████| 1/1 [00:00<00:00, 14.53it/s, epoch=343, loss=52.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.03it/s, epoch=344, loss=51.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.10it/s, epoch=345, loss=63.1]
# 100%|██████████| 1/1 [00:00<00:00, 13.49it/s, epoch=346, loss=42.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.02it/s, epoch=347, loss=43.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.67it/s, epoch=348, loss=39.8]
# 100%|██████████| 1/1 [00:00<00:00, 12.92it/s, epoch=349, loss=49.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.44it/s, epoch=350, loss=84.6]
# 100%|██████████| 1/1 [00:00<00:00, 15.35it/s, epoch=351, loss=40.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.70it/s, epoch=352, loss=40.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.22it/s, epoch=353, loss=56.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.89it/s, epoch=354, loss=49.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.92it/s, epoch=355, loss=56.8]
# 100%|██████████| 1/1 [00:00<00:00, 12.80it/s, epoch=356, loss=77.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.32it/s, epoch=357, loss=49.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.67it/s, epoch=358, loss=41]
# 100%|██████████| 1/1 [00:00<00:00, 15.28it/s, epoch=359, loss=38.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.55it/s, epoch=360, loss=47.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.17it/s, epoch=361, loss=83.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.81it/s, epoch=362, loss=43.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.85it/s, epoch=363, loss=50.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.54it/s, epoch=364, loss=50]
# 100%|██████████| 1/1 [00:00<00:00, 14.63it/s, epoch=365, loss=66.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.78it/s, epoch=366, loss=61.9]
# 100%|██████████| 1/1 [00:00<00:00, 11.15it/s, epoch=367, loss=51.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.26it/s, epoch=368, loss=43.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.63it/s, epoch=369, loss=47.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.45it/s, epoch=370, loss=57.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.54it/s, epoch=371, loss=37.2]
# 100%|██████████| 1/1 [00:00<00:00, 12.37it/s, epoch=372, loss=32.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.38it/s, epoch=373, loss=30.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.02it/s, epoch=374, loss=97]
# 100%|██████████| 1/1 [00:00<00:00, 13.75it/s, epoch=375, loss=55.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.40it/s, epoch=376, loss=52]
# 100%|██████████| 1/1 [00:00<00:00, 14.54it/s, epoch=377, loss=34.9]
# 100%|██████████| 1/1 [00:00<00:00, 15.43it/s, epoch=378, loss=66.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.21it/s, epoch=379, loss=53.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.95it/s, epoch=380, loss=61.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.54it/s, epoch=381, loss=53.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.63it/s, epoch=382, loss=52.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.30it/s, epoch=383, loss=29.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.71it/s, epoch=384, loss=57.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.80it/s, epoch=385, loss=71.1]
# 100%|██████████| 1/1 [00:00<00:00, 13.36it/s, epoch=386, loss=42]
# 100%|██████████| 1/1 [00:00<00:00, 14.20it/s, epoch=387, loss=59.1]
# 100%|██████████| 1/1 [00:00<00:00, 13.94it/s, epoch=388, loss=51]
# 100%|██████████| 1/1 [00:00<00:00, 13.25it/s, epoch=389, loss=44]
# 100%|██████████| 1/1 [00:00<00:00, 14.77it/s, epoch=390, loss=59.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.19it/s, epoch=391, loss=56.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.37it/s, epoch=392, loss=52.2]
# 100%|██████████| 1/1 [00:00<00:00, 10.98it/s, epoch=393, loss=62.8]
# 100%|██████████| 1/1 [00:00<00:00, 12.98it/s, epoch=394, loss=41.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.39it/s, epoch=395, loss=58.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.76it/s, epoch=396, loss=67.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.05it/s, epoch=397, loss=39.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.75it/s, epoch=398, loss=49.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.98it/s, epoch=399, loss=78.5]
# 100%|██████████| 1/1 [00:00<00:00, 15.77it/s, epoch=400, loss=91.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.36it/s, epoch=401, loss=54.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.08it/s, epoch=402, loss=39.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.15it/s, epoch=403, loss=68]
# 100%|██████████| 1/1 [00:00<00:00, 13.33it/s, epoch=404, loss=49.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.99it/s, epoch=405, loss=52.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.08it/s, epoch=406, loss=52.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.34it/s, epoch=407, loss=96.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.41it/s, epoch=408, loss=49.2]
# 100%|██████████| 1/1 [00:00<00:00, 12.81it/s, epoch=409, loss=47.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.00it/s, epoch=410, loss=48]
# 100%|██████████| 1/1 [00:00<00:00, 14.15it/s, epoch=411, loss=46.2]
# 100%|██████████| 1/1 [00:00<00:00, 15.61it/s, epoch=412, loss=50.9]
# 100%|██████████| 1/1 [00:00<00:00, 12.81it/s, epoch=413, loss=63.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.77it/s, epoch=414, loss=67.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.79it/s, epoch=415, loss=62.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.61it/s, epoch=416, loss=45]
# 100%|██████████| 1/1 [00:00<00:00, 14.13it/s, epoch=417, loss=45.4]
# 100%|██████████| 1/1 [00:00<00:00, 10.80it/s, epoch=418, loss=53]
# 100%|██████████| 1/1 [00:00<00:00, 14.65it/s, epoch=419, loss=41.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.29it/s, epoch=420, loss=42.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.37it/s, epoch=421, loss=32.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.03it/s, epoch=422, loss=72.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.87it/s, epoch=423, loss=54.3]
# 100%|██████████| 1/1 [00:00<00:00, 15.10it/s, epoch=424, loss=72.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.48it/s, epoch=425, loss=56.2]
# 100%|██████████| 1/1 [00:00<00:00, 15.07it/s, epoch=426, loss=48]
# 100%|██████████| 1/1 [00:00<00:00, 14.89it/s, epoch=427, loss=48.6]
# 100%|██████████| 1/1 [00:00<00:00, 15.41it/s, epoch=428, loss=101]
# 100%|██████████| 1/1 [00:00<00:00, 15.21it/s, epoch=429, loss=69.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.94it/s, epoch=430, loss=57.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.01it/s, epoch=431, loss=43.7]
# 100%|██████████| 1/1 [00:00<00:00, 12.83it/s, epoch=432, loss=38.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.48it/s, epoch=433, loss=42.5]
# 100%|██████████| 1/1 [00:00<00:00, 12.70it/s, epoch=434, loss=49.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.85it/s, epoch=435, loss=40.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.45it/s, epoch=436, loss=48.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.24it/s, epoch=437, loss=78]
# 100%|██████████| 1/1 [00:00<00:00, 14.04it/s, epoch=438, loss=53.4]
# 100%|██████████| 1/1 [00:00<00:00, 12.99it/s, epoch=439, loss=32]
# 100%|██████████| 1/1 [00:00<00:00, 13.46it/s, epoch=440, loss=60.6]
# 100%|██████████| 1/1 [00:00<00:00, 12.40it/s, epoch=441, loss=64.5]
# 100%|██████████| 1/1 [00:00<00:00, 10.11it/s, epoch=442, loss=52.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.18it/s, epoch=443, loss=59.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.89it/s, epoch=444, loss=40.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.32it/s, epoch=445, loss=52.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.74it/s, epoch=446, loss=68.5]
# 100%|██████████| 1/1 [00:00<00:00, 14.77it/s, epoch=447, loss=57.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.91it/s, epoch=448, loss=41.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.76it/s, epoch=449, loss=75.9]
# 100%|██████████| 1/1 [00:00<00:00, 12.53it/s, epoch=450, loss=42.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.60it/s, epoch=451, loss=83.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.41it/s, epoch=452, loss=60.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.18it/s, epoch=453, loss=64.7]
# 100%|██████████| 1/1 [00:00<00:00, 13.91it/s, epoch=454, loss=80.2]
# 100%|██████████| 1/1 [00:00<00:00, 13.42it/s, epoch=455, loss=50.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.28it/s, epoch=456, loss=56]
# 100%|██████████| 1/1 [00:00<00:00, 13.09it/s, epoch=457, loss=45.6]
# 100%|██████████| 1/1 [00:00<00:00, 15.02it/s, epoch=458, loss=51.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.29it/s, epoch=459, loss=83.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.30it/s, epoch=460, loss=50.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.76it/s, epoch=461, loss=39.2]
# 100%|██████████| 1/1 [00:00<00:00, 15.22it/s, epoch=462, loss=43.1]
# 100%|██████████| 1/1 [00:00<00:00, 12.79it/s, epoch=463, loss=62.3]
# 100%|██████████| 1/1 [00:00<00:00, 10.28it/s, epoch=464, loss=56.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.79it/s, epoch=465, loss=128]
# 100%|██████████| 1/1 [00:00<00:00, 15.38it/s, epoch=466, loss=38.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.84it/s, epoch=467, loss=50.4]
# 100%|██████████| 1/1 [00:00<00:00, 12.56it/s, epoch=468, loss=51]
# 100%|██████████| 1/1 [00:00<00:00, 14.40it/s, epoch=469, loss=35]
# 100%|██████████| 1/1 [00:00<00:00, 15.14it/s, epoch=470, loss=39.2]
# 100%|██████████| 1/1 [00:00<00:00, 12.79it/s, epoch=471, loss=42.1]
# 100%|██████████| 1/1 [00:00<00:00, 14.28it/s, epoch=472, loss=49.9]
# 100%|██████████| 1/1 [00:00<00:00, 15.12it/s, epoch=473, loss=49.4]
# 100%|██████████| 1/1 [00:00<00:00, 15.59it/s, epoch=474, loss=37.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.50it/s, epoch=475, loss=83.2]
# 100%|██████████| 1/1 [00:00<00:00, 16.79it/s, epoch=476, loss=54.4]
# 100%|██████████| 1/1 [00:00<00:00, 13.01it/s, epoch=477, loss=40.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.09it/s, epoch=478, loss=74.2]
# 100%|██████████| 1/1 [00:00<00:00, 15.67it/s, epoch=479, loss=57.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.40it/s, epoch=480, loss=69.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.08it/s, epoch=481, loss=47.1]
# 100%|██████████| 1/1 [00:00<00:00, 15.92it/s, epoch=482, loss=53.9]
# 100%|██████████| 1/1 [00:00<00:00, 14.67it/s, epoch=483, loss=45.3]
# 100%|██████████| 1/1 [00:00<00:00, 14.51it/s, epoch=484, loss=40.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.29it/s, epoch=485, loss=45.9]
# 100%|██████████| 1/1 [00:00<00:00, 10.74it/s, epoch=486, loss=57.9]
# 100%|██████████| 1/1 [00:00<00:00, 13.70it/s, epoch=487, loss=48.2]
# 100%|██████████| 1/1 [00:00<00:00, 14.88it/s, epoch=488, loss=52.6]
# 100%|██████████| 1/1 [00:00<00:00, 14.71it/s, epoch=489, loss=51.6]
# 100%|██████████| 1/1 [00:00<00:00, 15.20it/s, epoch=490, loss=57.5]
# 100%|██████████| 1/1 [00:00<00:00, 13.99it/s, epoch=491, loss=83.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.46it/s, epoch=492, loss=66.7]
# 100%|██████████| 1/1 [00:00<00:00, 15.04it/s, epoch=493, loss=93.8]
# 100%|██████████| 1/1 [00:00<00:00, 14.61it/s, epoch=494, loss=56.4]
# 100%|██████████| 1/1 [00:00<00:00, 14.50it/s, epoch=495, loss=45]
# 100%|██████████| 1/1 [00:00<00:00, 12.98it/s, epoch=496, loss=50.6]
# 100%|██████████| 1/1 [00:00<00:00, 13.49it/s, epoch=497, loss=52.7]
# 100%|██████████| 1/1 [00:00<00:00, 14.60it/s, epoch=498, loss=47.8]
# 100%|██████████| 1/1 [00:00<00:00, 13.55it/s, epoch=499, loss=61.3]

# %%
visualize_dds_2d(device, model, dataset, multipliers=(1, 1))
